# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales_data_sample.csv', encoding='ISO-8859-1')

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# ADDRESSLINE2        2521
# STATE               1486
# TERRITORY           1074
# POSTALCODE            76
# SALES                  0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# ORDERNUMBER            0
# MONTH_ID               0
# QTR_ID                 0
# STATUS                 0
# ORDERDATE              0
# PRODUCTCODE            0
# YEAR_ID                0
# MSRP                   0
# PRODUCTLINE            0
# ADDRESSLINE1           0
# PHONE                  0
# CUSTOMERNAME           0
# CITY                   0
# COUNTRY                0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.drop('ADDRESSLINE2',axis = 1, inplace = True)

# %%
df['STATE'].head(5)
# Out:
# 0     NY
# 1    NaN
# 2    NaN
# 3     CA
# 4     CA
# Name: STATE, dtype: object

# %%
df.drop('STATE',axis=1,inplace=True)

# %%
df['TERRITORY'].head(10)
# Out:
# 0     NaN
# 1    EMEA
# 2    EMEA
# 3     NaN
# 4     NaN
# 5     NaN
# 6    EMEA
# 7    EMEA
# 8     NaN
# 9    EMEA
# Name: TERRITORY, dtype: object

# %%
df.drop('TERRITORY',axis=1,inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# POSTALCODE          76
# ORDERNUMBER          0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# QUANTITYORDERED      0
# ORDERDATE            0
# STATUS               0
# MONTH_ID             0
# QTR_ID               0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# YEAR_ID              0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# CITY                 0
# COUNTRY              0
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %%
df['POSTALCODE'].head(10)
# Out:
# 0     10022
# 1     51100
# 2     75508
# 3     90003
# 4       NaN
# 5     94217
# 6     59000
# 7    N 5804
# 8       NaN
# 9     75016
# Name: POSTALCODE, dtype: object

# %%
df['ADDRESSLINE1'].head(10)
# Out:
# 0          897 Long Airport Avenue
# 1               59 rue de l'Abbaye
# 2    27 rue du Colonel Pierre Avia
# 3               78934 Hillside Dr.
# 4                  7734 Strong St.
# 5                9408 Furth Circle
# 6          184, chausse de Tournai
# 7      Drammen 121, PR 744 Sentrum
# 8        5557 North Pendale Street
# 9                25, rue Lauriston
# Name: ADDRESSLINE1, dtype: object

# %%
df.drop('POSTALCODE',axis=1,inplace=True)

# %%
df.shape
# Out:
# (2823, 21)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'CITY', 'COUNTRY', 'CONTACTLASTNAME',
#        'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# COUNTRY             0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
import seaborn as sns

# %%
# Set the style and color palette
sns.set_style("whitegrid")
sns.set_palette("pastel")

# %%
# Distribution of Sales
plt.figure(figsize=(8,6))
sns.histplot(df['SALES'], kde=True, color='blue',palette='pastel')
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_2060\1771288628.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['SALES'], kde=True, color='blue',palette='pastel')

# %%
#Quantity Ordered by Deal Size: This will show the relationship between QUANTITYORDERED and DEALSIZE.
plt.figure(figsize=(8, 6))
sns.lineplot(x='DEALSIZE', y='QUANTITYORDERED', data=df,palette='pastel')
plt.title('Quantity Ordered by Deal Size')
plt.xlabel('Deal Size')
plt.ylabel('Quantity Ordered')
plt.show()
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_2060\3842995315.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='DEALSIZE', y='QUANTITYORDERED', data=df,palette='pastel')

# %%
#Sales Over Time (Month-wise): We can see how sales have varied over the months.
plt.figure(figsize=(8, 6))
sns.lineplot(x='MONTH_ID', y='SALES', data=df)
plt.title('Sales Over Months')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
#Sales by Product Line: Compare sales across different product lines.
plt.figure(figsize=(8, 6))
sns.barplot(x='PRODUCTLINE', y='SALES', color= 'violet', data=df, estimator=sum)
plt.title('Total Sales by Product Line')
plt.xticks(rotation=45)
plt.xlabel('Product Line')
plt.ylabel('Total Sales')
plt.show()

# %%
#Deal Size Count Plot: Count the occurrences of each DEALSIZE.
plt.figure(figsize=(6, 6))
sns.countplot(x='DEALSIZE', data=df,palette='pastel')
plt.title('Count of Deal Size')
plt.xlabel('Deal Size')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_2060\2611611389.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='DEALSIZE', data=df,palette='pastel')

# %%
#Sales by Country: This can show which countries generate the most sales
plt.figure(figsize=(8, 6))
sns.barplot(x='COUNTRY', y='SALES', data=df, estimator=sum)
plt.title('Total Sales by Country')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.show()

# %%
#Sales vs. MSRP: Investigate the relationship between the MSRP (Manufacturer's Suggested Retail Price) and SALES.
plt.figure(figsize=(8, 6))
sns.scatterplot(x='MSRP', y='SALES', data=df,palette='pastel')
plt.title('Sales vs. MSRP')
plt.xlabel('MSRP')
plt.ylabel('Sales')
plt.show()
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_2060\1375868470.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='MSRP', y='SALES', data=df,palette='pastel')

# %%
#Sales by Year: Total sales broken down by year
plt.figure(figsize=(6, 6))
sns.barplot(x='YEAR_ID', y='SALES', data=df, estimator=sum,palette='pastel')
plt.title('Total Sales by Year')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.show()
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_2060\3123347320.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='YEAR_ID', y='SALES', data=df, estimator=sum,palette='pastel')

# %%
# Save the DataFrame to a new CSV file
df.to_csv('processed_sales_data.csv', index=False)
